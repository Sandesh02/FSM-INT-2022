# %% [markdown]
# ## Classes
#
# The following 38 classes are availaible in the dataset
#
# - `Apple___Apple_scab`
# - `Apple___Black_rot`
# - `Apple___Cedar_apple_rust`
# - `Apple___healthy`
# - `Blueberry___healthy`
# - `Cherry_(including_sour)___Powdery_mildew`
# - `Cherry_(including_sour)___healthy`
# - `Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot`
# - `Corn_(maize)___Common_rust_`
# - `Corn_(maize)___Northern_Leaf_Blight`
# - `Corn_(maize)___healthy', 'Grape___Black_rot`
# - `Grape___Leaf_blight_(Isariopsis_Leaf_Spot)`
# - `Grape___healthy`
# - `Orange___Haunglongbing_(Citrus_greening)`
# - `Peach___Bacterial_spot`
# - `Peach___healthy`
# - `Pepper,_bell___Bacterial_spot`
# - `Pepper,_bell___healthy`
# - `Potato___Early_blight`
# - `Potato___Late_blight`
# - `Potato___healthy`
# - `Raspberry___healthy`
# - `Soybean___healthy`
# - `Squash___Powdery_mildew`
# - `Strawberry___Leaf_scorch`
# - `Strawberry___healthy`
# - `Tomato___Bacterial_spot`
# - `Tomato___Late_blight`
# - `Tomato___Leaf_Mold`
# - `Tomato___Septoria_leaf_spot`
# - `Tomato___Spider_mites Two-spotted_spider_mite`
# - `Tomato___Target_Spot`
# - `Tomato___Tomato_Yellow_Leaf_Curl_Virus`
# - `Tomato___Tomato_mosaic_virus`
# - `Tomato___healthy`

# %% [markdown]
# ## Setup

# %%
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np

import os

# %%
image_size = 224
target_size = (image_size, image_size)
input_shape = (image_size, image_size, 3)

batch_size = 32
epochs = 15

# %%
base_dir = "../input/new-plant-diseases-dataset/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)"
train_dir = os.path.join(base_dir,"train")
test_dir = os.path.join(base_dir,"valid")

# %%
train_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0,
                                                             shear_range = 0.2,
                                                             zoom_range = 0.2,
                                                             width_shift_range = 0.2,
                                                             height_shift_range = 0.2,
                                                             fill_mode="nearest")

test_datagen = keras.preprocessing.image.ImageDataGenerator(rescale = 1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size = (image_size, image_size),
                                               batch_size = 32,
                                               class_mode = "categorical")

test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size = (image_size, image_size),
                                             batch_size = 32,
                                             class_mode = "categorical")
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.

# %%
categories = list(train_data.class_indices.keys())

# %%
import json
with open('class_indices.json','w') as f:
  json.dump(train_data.class_indices, f)

from IPython.display import FileLink
FileLink(r'class_indices.json')
# Out:
# /kaggle/working/class_indices.json

# %% [markdown]
# ## Training

# %%
base_model = tf.keras.applications.mobilenet.MobileNet(weights = "/kaggle/input/keras-pretrain-model-weights/mobilenet_1_0_224_tf_no_top.h5",
                                             include_top = False,
                                             input_shape = input_shape)

base_model.trainable = False

# %%
inputs = keras.Input(shape = input_shape)

x = base_model(inputs, training = False)
x = tf.keras.layers.GlobalAveragePooling2D()(x)
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(len(categories), activation="softmax")(x)

model = keras.Model(inputs = inputs, 
                    outputs = x, 
                    name="LeafDisease_MobileNet")

# %%
optimizer = tf.keras.optimizers.Adam()

model.compile(optimizer = optimizer,
              loss = tf.keras.losses.CategoricalCrossentropy(from_logits = True),
              metrics=[keras.metrics.CategoricalAccuracy(), 
                       'accuracy'])

# %%
history = model.fit(train_data,
                    validation_data=test_data,
                    epochs=20,
                    steps_per_epoch=150,
                    validation_steps=100)
# Out:
# Epoch 1/20
# 150/150 [==============================] - 270s 2s/step - loss: 2.9195 - categorical_accuracy: 0.2697 - accuracy: 0.2697 - val_loss: 0.7941 - val_categorical_accuracy: 0.8044 - val_accuracy: 0.8044
# Epoch 2/20
# 150/150 [==============================] - 266s 2s/step - loss: 0.8745 - categorical_accuracy: 0.7484 - accuracy: 0.7484 - val_loss: 0.4922 - val_categorical_accuracy: 0.8647 - val_accuracy: 0.8647
# Epoch 3/20
# 150/150 [==============================] - 277s 2s/step - loss: 0.5967 - categorical_accuracy: 0.8297 - accuracy: 0.8297 - val_loss: 0.4098 - val_categorical_accuracy: 0.8822 - val_accuracy: 0.8822
# Epoch 4/20
# 150/150 [==============================] - 282s 2s/step - loss: 0.4780 - categorical_accuracy: 0.8645 - accuracy: 0.8645 - val_loss: 0.3167 - val_categorical_accuracy: 0.9134 - val_accuracy: 0.9134
# Epoch 5/20
# 150/150 [==============================] - 268s 2s/step - loss: 0.4402 - categorical_accuracy: 0.8742 - accuracy: 0.8742 - val_loss: 0.2902 - val_categorical_accuracy: 0.9169 - val_accuracy: 0.9169
# Epoch 6/20
# 150/150 [==============================] - 277s 2s/step - loss: 0.3787 - categorical_accuracy: 0.8854 - accuracy: 0.8854 - val_loss: 0.2630 - val_categorical_accuracy: 0.9228 - val_accuracy: 0.9228
# Epoch 7/20
# 150/150 [==============================] - 282s 2s/step - loss: 0.3451 - categorical_accuracy: 0.8961 - accuracy: 0.8961 - val_loss: 0.2506 - val_categorical_accuracy: 0.9259 - val_accuracy: 0.9259
# Epoch 8/20
# 150/150 [==============================] - 262s 2s/step - loss: 0.3237 - categorical_accuracy: 0.8960 - accuracy: 0.8960 - val_loss: 0.2207 - val_categorical_accuracy: 0.9325 - val_accuracy: 0.9325
# Epoch 9/20
# 150/150 [==============================] - 262s 2s/step - loss: 0.2960 - categorical_accuracy: 0.9113 - accuracy: 0.9113 - val_loss: 0.2200 - val_categorical_accuracy: 0.9344 - val_accuracy: 0.9344
# Epoch 10/20
# 150/150 [==============================] - 262s 2s/step - loss: 0.2838 - categorical_accuracy: 0.9145 - accuracy: 0.9145 - val_loss: 0.2090 - val_categorical_accuracy: 0.9316 - val_accuracy: 0.9316
# Epoch 11/20
# 150/150 [==============================] - 259s 2s/step - loss: 0.3091 - categorical_accuracy: 0.9083 - accuracy: 0.9083 - val_loss: 0.2097 - val_categorical_accuracy: 0.9337 - val_accuracy: 0.9337
# Epoch 12/20
# 150/150 [==============================] - 259s 2s/step - loss: 0.2602 - categorical_accuracy: 0.9220 - accuracy: 0.9220 - val_loss: 0.1955 - val_categorical_accuracy: 0.9444 - val_accuracy: 0.9444
# Epoch 13/20
# 150/150 [==============================] - 259s 2s/step - loss: 0.2702 - categorical_accuracy: 0.9157 - accuracy: 0.9157 - val_loss: 0.1680 - val_categorical_accuracy: 0.9494 - val_accuracy: 0.9494
# Epoch 14/20
# 150/150 [==============================] - 259s 2s/step - loss: 0.2518 - categorical_accuracy: 0.9175 - accuracy: 0.9175 - val_loss: 0.1773 - val_categorical_accuracy: 0.9488 - val_accuracy: 0.9488
# Epoch 15/20
# 150/150 [==============================] - 259s 2s/step - loss: 0.2337 - categorical_accuracy: 0.9300 - accuracy: 0.9300 - val_loss: 0.1700 - val_categorical_accuracy: 0.9422 - val_accuracy: 0.9422
# Epoch 16/20
# 150/150 [==============================] - 258s 2s/step - loss: 0.2618 - categorical_accuracy: 0.9147 - accuracy: 0.9147 - val_loss: 0.1731 - val_categorical_accuracy: 0.9441 - val_accuracy: 0.9441
# Epoch 17/20
# 150/150 [==============================] - 257s 2s/step - loss: 0.2522 - categorical_accuracy: 0.9226 - accuracy: 0.9226 - val_loss: 0.1855 - val_categorical_accuracy: 0.9397 - val_accuracy: 0.9397
# Epoch 18/20
# 150/150 [==============================] - 257s 2s/step - loss: 0.2473 - categorical_accuracy: 0.9202 - accuracy: 0.9202 - val_loss: 0.1584 - val_categorical_accuracy: 0.9481 - val_accuracy: 0.9481
# Epoch 19/20
# 150/150 [==============================] - 260s 2s/step - loss: 0.1990 - categorical_accuracy: 0.9339 - accuracy: 0.9339 - val_loss: 0.1800 - val_categorical_accuracy: 0.9406 - val_accuracy: 0.9406
# Epoch 20/20
# 150/150 [==============================] - 263s 2s/step - loss: 0.2196 - categorical_accuracy: 0.9293 - accuracy: 0.9293 - val_loss: 0.1564 - val_categorical_accuracy: 0.9516 - val_accuracy: 0.9516

# %% [markdown]
# ## Review the training process

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

fig = plt.figure(figsize=(10,6))
plt.plot(epochs,loss,c="red",label="Training")
plt.plot(epochs,val_loss,c="blue",label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']

epochs = range(len(acc))

fig = plt.figure(figsize=(10,6))
plt.plot(epochs,acc,c="red",label="Training")
plt.plot(epochs,val_acc,c="blue",label="Validation")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %% [markdown]
# ## Save the model
#
# We finally save the model in the standard TensorFlow 2 SavedModel format.

# %%
model.save('plant_disease.h5')

# %%
model = tf.keras.models.load_model('/kaggle/working/plant_disease.h5')
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open("plant_disease.tflite", "wb").write(tflite_model)
# Out:
# 12962772
